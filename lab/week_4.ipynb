# %%
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
print(titanic.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
objective = 'Classification: Survived (Yes/No)'
success_criteria = "Accuracy >80%"
constraints = "Limited values,Missing values,imbalance classes ";
print("Objectives: ",objective)
print( "Success Criteria: ",success_criteria)
print("Constraints: ", constraints)
# Out:
# Objectives:  Classification: Survived (Yes/No)
# Success Criteria:  Accuracy >80%
# Constraints:  Limited values,Missing values,imbalance classes

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset("iris")
print("Data shape: ", df.shape)
print(df.head())
print(df.info())
print(df.describe())
# Out:
# Data shape:  (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import pandas as pd
df = pd.read_csv("Iris.csv")
print(df.shape)
print(df.head())
# Out:
# (150, 6)
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import seaborn as sns
df = sns.load_dataset("titanic")
print(df.head())
print(df.column)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
df=sns.load_dataset("titanic")
df['age'].fillna(df['age'].median(), inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
df.drop_duplicates(inplace = True)
df = pd.get_dummies(df,columns = ['sex','class','embarked'],drop_first = True)
df['family_size'] = df['sibsp']+df['parch']
print(df.head())
# Out:
#    survived  pclass   age  sibsp  parch     fare    who  adult_male deck  \
# 0         0       3  22.0      1      0   7.2500    man        True  NaN
# 1         1       1  38.0      1      0  71.2833  woman       False    C
# 2         1       3  26.0      0      0   7.9250  woman       False  NaN
# 3         1       1  35.0      1      0  53.1000  woman       False    C
# 4         0       3  35.0      0      0   8.0500    man        True  NaN
#
#    embark_town alive  alone  sex_male  class_Second  class_Third  embarked_Q  \
# 0  Southampton    no  False      True         False         True       False
# 1    Cherbourg   yes  False     False         False        False       False
# 2  Southampton   yes   True     False         False         True       False
# 3  Southampton   yes  False     False         False        False       False
# 4  Southampton    no   True      True         False         True       False
#
#    embarked_S  family_size
# 0        True            1
# 1       False            1
# 2        True            0
# 3        True            1
# 4        True            0
# C:\Users\meghn\AppData\Local\Temp\ipykernel_18352\2778179478.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['age'].fillna(df['age'].median(), inplace=True)
# C:\Users\meghn\AppData\Local\Temp\ipykernel_18352\2778179478.py:4: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
import seaborn as sns
df=sns.load_dataset("titanic")
df['age'] = df['age'].fillna(df['age'].median())
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

df.drop_duplicates(inplace=True)

df = pd.get_dummies(
    df,
    columns=['sex', 'class', 'embarked'],
    drop_first=True
)

df['family_size'] = df['sibsp'] + df['parch']

print(df.head())
# Out:
#    survived  pclass   age  sibsp  parch     fare    who  adult_male deck  \
# 0         0       3  22.0      1      0   7.2500    man        True  NaN
# 1         1       1  38.0      1      0  71.2833  woman       False    C
# 2         1       3  26.0      0      0   7.9250  woman       False  NaN
# 3         1       1  35.0      1      0  53.1000  woman       False    C
# 4         0       3  35.0      0      0   8.0500    man        True  NaN
#
#    embark_town alive  alone  sex_male  class_Second  class_Third  embarked_Q  \
# 0  Southampton    no  False      True         False         True       False
# 1    Cherbourg   yes  False     False         False        False       False
# 2  Southampton   yes   True     False         False         True       False
# 3  Southampton   yes  False     False         False        False       False
# 4  Southampton    no   True      True         False         True       False
#
#    embarked_S  family_size
# 0        True            1
# 1       False            1
# 2        True            0
# 3        True            1
# 4        True            0

# %%
import pandas as pd
df = pd.read_csv("student.csv")
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print(df.shape)
# Out:
#    Unnamed: 0  roll_no Name   Age  Section  Datascience_marks  QC_Marks  \
# 0           0      101    a  21.0        1                 86        96
# 1           1      102    b  22.0        2                 87        85
# 2           2      103    c  23.0        3                 85        74
# 3           3      104    d  24.0        1                 96        56
# 4           4      105    e  25.0        2                 74        85
#
#    TOC_marks
# 0         85
# 1         96
# 2         74
# 3         85
# 4         96
#    Unnamed: 0  roll_no Name   Age  Section  Datascience_marks  QC_Marks  \
# 5           5      106    f   NaN        3                 85        96
# 6           6      107    g  27.0        4                 96        52
# 7           7      108    h  28.0        5                 74        74
# 8           8      109    i  22.0        1                 85        85
# 9           9      110    j  24.0        2                 96        96
#
#    TOC_marks
# 5         75
# 6         63
# 7         52
# 8         74
# 9         52
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         10 non-null     int64
#  1   roll_no            10 non-null     int64
#  2   Name               10 non-null     str
#  3   Age                9 non-null      float64
#  4   Section            10 non-null     int64
#  5   Datascience_marks  10 non-null     int64
#  6   QC_Marks           10 non-null     int64
#  7   TOC_marks          10 non-null     int64
# dtypes: float64(1), int64(6), str(1)
# memory usage: 772.0 bytes
# None
#        Unnamed: 0    roll_no        Age    Section  Datascience_marks  \
# count    10.00000   10.00000   9.000000  10.000000          10.000000
# mean      4.50000  105.50000  24.000000   2.400000          86.400000
# std       3.02765    3.02765   2.345208   1.349897           8.099383
# min       0.00000  101.00000  21.000000   1.000000          74.000000
# 25%       2.25000  103.25000  22.000000   1.250000          85.000000
# 50%       4.50000  105.50000  24.000000   2.000000          85.500000
# 75%       6.75000  107.75000  25.000000   3.000000          93.750000
# max       9.00000  110.00000  28.000000   5.000000          96.000000
#
#         QC_Marks  TOC_marks
# count  10.000000  10.000000
# mean   79.900000  75.200000
# std    15.898637  15.935983
# min    52.000000  52.000000
# 25%    74.000000  65.750000
# 50%    85.000000  74.500000
# 75%    93.250000  85.000000
# max    96.000000  96.000000
# (10, 8)

# %%
import pandas as pd
df = pd.read_csv("student.csv")
df['Age'] = df['Age'].fillna(df['Age'].median())
print(df.tail())
# Out:
#    Unnamed: 0  roll_no Name   Age  Section  Datascience_marks  QC_Marks  \
# 5           5      106    f  24.0        3                 85        96
# 6           6      107    g  27.0        4                 96        52
# 7           7      108    h  28.0        5                 74        74
# 8           8      109    i  22.0        1                 85        85
# 9           9      110    j  24.0        2                 96        96
#
#    TOC_marks
# 5         75
# 6         63
# 7         52
# 8         74
# 9         52

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("titanic")

# Age distribution
sns.histplot(df['age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.show()

# Fare distribution
sns.histplot(df['fare'], bins=10, kde=True)
plt.title("Fare Distribution")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("student.csv")
sns.histplot(df['Age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("titanic")
corr = df.corr(numeric_only=True)
print(corr)
sns.heatmap(corr, annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Studnet.csv')
corr = df.corr(numeric_only=True)
print(corr)
sns.heatmap(corr, annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#                Student_ID       Age  Attendance  Math_Score  Science_Score
# Student_ID       1.000000  0.140040    0.046469    0.196933       0.189121
# Age              0.140040  1.000000    0.241682    0.323176       0.214542
# Attendance       0.046469  0.241682    1.000000    0.961283       0.948883
# Math_Score       0.196933  0.323176    0.961283    1.000000       0.975996
# Science_Score    0.189121  0.214542    0.948883    0.975996       1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("titanic")
corr = df.corr(numeric_only=True)
print(corr)
sns.heatmap(corr, annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000
